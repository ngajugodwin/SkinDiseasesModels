# %%
import numpy as np
import os
import pandas as pd
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img,img_to_array
# Out:
# 2024-04-07 03:42:59.495450: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_dir = Path('skin diseases/train')
train_filepaths = list(train_dir.glob(r'**/*.jpg'))
test_dir = Path('skin diseases/test')
test_filepaths = list(test_dir.glob(r'**/*.jpg'))
val_dir = Path('skin diseases/valid')
val_filepaths = list(test_dir.glob(r'**/*.jpg'))

# %%
def image_processing(filepath):
    """ Create a DataFrame with the filepath and the labels of the pictures
    """

    labels = [str(filepath[i]).split("/")[-2] \
              for i in range(len(filepath))]

    filepath = pd.Series(filepath, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    # Concatenate filepaths and labels
    df = pd.concat([filepath, labels], axis=1)

    # Shuffle the DataFrame and reset index
    df = df.sample(frac=1).reset_index(drop = True)
    
    return df

# %%
train_df = image_processing(train_filepaths)
test_df = image_processing(test_filepaths)
val_df = image_processing(val_filepaths)

# %%
print('-- Training set --\n')
print(f'Number of pictures: {train_df.shape[0]}\n')
print(f'Number of different labels: {len(train_df.Label.unique())}\n')
print(f'Labels: {train_df.Label.unique()}')
# Out:
# -- Training set --
#
# Number of pictures: 7012
#
# Number of different labels: 12
#
# Labels: ['melanoma' 'acne' 'bcc' 'actinic keratosis' 'nevus'
#  'basal cell carcinoma' 'pigmented benign keratosis' 'atopic'
#  'vascular lesion' 'squamous cell carcinoma' 'dermatofibroma'
#  'seborrheic keratosis']

# %%
train_df.head(5)
# Out:
#                                             Filepath     Label
# 0      skin diseases/train/melanoma/ISIC_0010372.jpg  melanoma
# 1  skin diseases/train/acne/144__ProtectWyJQcm90Z...      acne
# 2  skin diseases/train/bcc/basal-cell-carcinoma-f...       bcc
# 3  skin diseases/train/acne/acne-excoriated-17_jp...      acne
# 4      skin diseases/train/melanoma/ISIC_0000401.jpg  melanoma

# %%
# Create a DataFrame with one Label of each category
df_unique = train_df.copy().drop_duplicates(subset=["Label"]).reset_index()

# Display some pictures of the dataset
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(8, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(df_unique.Filepath[i]))
    ax.set_title(df_unique.Label[i], fontsize = 12)
plt.tight_layout(pad=0.5)
plt.show()

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 7012 validated image filenames belonging to 12 classes.

# %%
val_images = train_generator.flow_from_dataframe(
    dataframe=val_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 323 validated image filenames belonging to 12 classes.

# %%
test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 323 validated image filenames belonging to 12 classes.

# %%
pretrained_model = tf.keras.applications.ResNet50(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)
pretrained_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 3s 0us/step

# %%
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(12, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    validation_data=train_images,
    batch_size = 32,
    epochs=10,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=2,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/10
# 2024-04-07 03:51:24.083398: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 220/220 [==============================] - ETA: 0s - loss: 0.8954 - accuracy: 0.6640
# 2024-04-07 03:56:15.330978: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 220/220 [==============================] - 599s 3s/step - loss: 0.8954 - accuracy: 0.6640 - val_loss: 0.6271 - val_accuracy: 0.7644
# Epoch 2/10
# 220/220 [==============================] - 653s 3s/step - loss: 0.6107 - accuracy: 0.7671 - val_loss: 0.4928 - val_accuracy: 0.8186
# Epoch 3/10
# 220/220 [==============================] - 634s 3s/step - loss: 0.5193 - accuracy: 0.8055 - val_loss: 0.4062 - val_accuracy: 0.8478
# Epoch 4/10
# 220/220 [==============================] - 645s 3s/step - loss: 0.4203 - accuracy: 0.8411 - val_loss: 0.3691 - val_accuracy: 0.8592
# Epoch 5/10
# 220/220 [==============================] - 635s 3s/step - loss: 0.3854 - accuracy: 0.8477 - val_loss: 0.3273 - val_accuracy: 0.8768
# Epoch 6/10
# 220/220 [==============================] - 717s 3s/step - loss: 0.3268 - accuracy: 0.8766 - val_loss: 0.2763 - val_accuracy: 0.8922
# Epoch 7/10
# 220/220 [==============================] - 705s 3s/step - loss: 0.2900 - accuracy: 0.8906 - val_loss: 0.2331 - val_accuracy: 0.9109
# Epoch 8/10
# 220/220 [==============================] - 703s 3s/step - loss: 0.2309 - accuracy: 0.9169 - val_loss: 0.2326 - val_accuracy: 0.9086
# Epoch 9/10
# 220/220 [==============================] - 684s 3s/step - loss: 0.2333 - accuracy: 0.9087 - val_loss: 0.2485 - val_accuracy: 0.9023
# Epoch 10/10
# 220/220 [==============================] - 737s 3s/step - loss: 0.1992 - accuracy: 0.9204 - val_loss: 0.1821 - val_accuracy: 0.9321

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Model accuracy")
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'])

plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Model loss")
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'])

plt.show()
