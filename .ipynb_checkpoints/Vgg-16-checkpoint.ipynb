# %%
import numpy as np
import os
import pandas as pd
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img,img_to_array
# Out:
# 2024-04-06 05:06:11.457966: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_dir = Path('skin diseases/train')
train_filepaths = list(train_dir.glob(r'**/*.jpg'))
test_dir = Path('skin diseases/test')
test_filepaths = list(test_dir.glob(r'**/*.jpg'))
val_dir = Path('skin diseases/valid')
val_filepaths = list(test_dir.glob(r'**/*.jpg'))

# %%
def image_processing(filepath):
    """ Create a DataFrame with the filepath and the labels of the pictures
    """

    labels = [str(filepath[i]).split("/")[-2] \
              for i in range(len(filepath))]

    filepath = pd.Series(filepath, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    # Concatenate filepaths and labels
    df = pd.concat([filepath, labels], axis=1)

    # Shuffle the DataFrame and reset index
    df = df.sample(frac=1).reset_index(drop = True)
    
    return df

# %%
train_df = image_processing(train_filepaths)
test_df = image_processing(test_filepaths)
val_df = image_processing(val_filepaths)

# %%
print('-- Training set --\n')
print(f'Number of pictures: {train_df.shape[0]}\n')
print(f'Number of different labels: {len(train_df.Label.unique())}\n')
print(f'Labels: {train_df.Label.unique()}')
# Out:
# -- Training set --
#
# Number of pictures: 7012
#
# Number of different labels: 12
#
# Labels: ['atopic' 'bcc' 'acne' 'pigmented benign keratosis' 'vascular lesion'
#  'nevus' 'melanoma' 'dermatofibroma' 'seborrheic keratosis'
#  'basal cell carcinoma' 'squamous cell carcinoma' 'actinic keratosis']

# %%
train_df.head(5)
# Out:
#                                             Filepath   Label
# 0  skin diseases/train/atopic/10_28_jpg.rf.1a430b...  atopic
# 1  skin diseases/train/bcc/sdfds_jpg.rf.258cccc4a...     bcc
# 2  skin diseases/train/acne/acne-cystic-44_jpg.rf...    acne
# 3  skin diseases/train/atopic/6_152_jpg.rf.fcd9f9...  atopic
# 4  skin diseases/train/atopic/6_207_jpg.rf.996a32...  atopic

# %%
# Create a DataFrame with one Label of each category
df_unique = train_df.copy().drop_duplicates(subset=["Label"]).reset_index()

# Display some pictures of the dataset
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(8, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(df_unique.Filepath[i]))
    ax.set_title(df_unique.Label[i], fontsize = 12)
plt.tight_layout(pad=0.5)
plt.show()

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 7012 validated image filenames belonging to 12 classes.

# %%
val_images = train_generator.flow_from_dataframe(
    dataframe=val_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 323 validated image filenames belonging to 12 classes.

# %%
test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 323 validated image filenames belonging to 12 classes.

# %%
pretrained_model = tf.keras.applications.VGG16(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)
pretrained_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %%
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(12, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    validation_data=train_images,
    batch_size = 32,
    epochs=10, #5,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=2,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/10
# 2024-04-06 05:29:54.727601: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 220/220 [==============================] - ETA: 0s - loss: 1.0371 - accuracy: 0.6134
# 2024-04-06 05:37:19.311304: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 220/220 [==============================] - 894s 4s/step - loss: 1.0371 - accuracy: 0.6134 - val_loss: 0.7498 - val_accuracy: 0.7143
# Epoch 2/10
# 220/220 [==============================] - 963s 4s/step - loss: 0.7183 - accuracy: 0.7375 - val_loss: 0.6091 - val_accuracy: 0.7754
# Epoch 3/10
# 220/220 [==============================] - 938s 4s/step - loss: 0.6037 - accuracy: 0.7804 - val_loss: 0.5308 - val_accuracy: 0.8006
# Epoch 4/10
# 220/220 [==============================] - 1197s 5s/step - loss: 0.5010 - accuracy: 0.8136 - val_loss: 0.4201 - val_accuracy: 0.8477
# Epoch 5/10
# 220/220 [==============================] - 1312s 6s/step - loss: 0.4474 - accuracy: 0.8301 - val_loss: 0.3740 - val_accuracy: 0.8644
# Epoch 6/10
# 220/220 [==============================] - ETA: 0s - loss: 0.3792 - accuracy: 0.8601
